# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mp
import seaborn as sns

df=pd.read_csv('Customer Churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# # changed data type of total charges and replaced blanks with 0 in it

# %%
df["TotalCharges"]=df["TotalCharges"].replace(" ","0")
df["TotalCharges"]=df["TotalCharges"].astype("float")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
def convert(value):
    if value==1:
        return "yes"
    else:
        return "no"

df['SeniorCitizen']=df['SeniorCitizen'].apply(convert)
df.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            no     Yes         No       1           No
# 1  5575-GNVDE    Male            no      No         No      34          Yes
# 2  3668-QPYBK    Male            no      No         No       2          Yes
# 3  7795-CFOCW    Male            no      No         No      45           No
# 4  9237-HQITU  Female            no      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# # Changed values in SeniorCitizen cell from 0 = no and 1 = false

# %%
ax=sns.countplot( x = "Churn" , data = df )
ax.bar_label(ax.containers[0])
mp.title("Count of Churned Customers" , fontsize=12)
mp.show()

# %% [markdown]
# # This countplot tells the count of customers churned

# %%
mp.figure(figsize=(4,4))
gb=df.groupby("Churn").agg({'Churn' : "count"})
mp.pie(gb['Churn'] , labels=gb.index , autopct = "%1.2f%%")
mp.title("Percentage of Customers Churned", fontsize=12)
mp.show()

# %% [markdown]
# # By this we came to know that 26% customers churned.

# %%
mp.figure(figsize=(4,5))
sns.countplot(x="gender", data= df , hue="Churn")
mp.title("Churn by Gender")
mp.show()

# %% [markdown]
# # This graph tells us the Churn based on gender

# %%
mp.figure(figsize=(4,5))
ax=sns.countplot(x="SeniorCitizen", data= df )
ax.bar_label(ax.containers[0])
mp.title("Count of SeniorCitizen")
mp.show()

# %%
# Assuming `df` is your dataframe and contains columns 'SeniorCitizen' and 'Churn'

# Calculate percentages
grouped = df.groupby(['SeniorCitizen', 'Churn']).size().reset_index(name='Count')
total = grouped.groupby('SeniorCitizen')['Count'].transform('sum')
grouped['Percentage'] = grouped['Count'] / total * 100

# Pivot the data for a stacked bar chart
pivot = grouped.pivot(index='SeniorCitizen', columns='Churn', values='Percentage').fillna(0)

# Define a color palette with distinct colors
palette = sns.color_palette("viridis", n_colors=len(pivot.columns))

# Plot the stacked bar chart
fig, ax = mp.subplots(figsize=(6, 5))

bottom_values = [0] * len(pivot.index)  # Track bottom values for stacking

for idx, column in enumerate(pivot.columns):
    ax.bar(
        pivot.index, 
        pivot[column], 
        bottom=bottom_values, 
        color=palette[idx],  # Use a unique color for each category
        label=column
    )
    
    # Add percentage labels
    for i, val in enumerate(pivot[column]):
        if val > 0:  # Skip labels for 0% segments
            ax.text(
                i, 
                bottom_values[i] + val / 2, 
                f'{val:.1f}%', 
                ha='center', 
                va='center', 
                fontsize=9, 
                color='white'
            )
    # Update bottom values for the next stacked segment
    bottom_values = [b + v for b, v in zip(bottom_values, pivot[column])]

# Customize the plot
ax.set_title('Churn by SeniorCitizen (Percentage)')
ax.set_ylabel('Percentage')
ax.set_xlabel('SeniorCitizen')
ax.set_xticks(range(len(pivot.index)))
ax.set_xticklabels(pivot.index, rotation=0)  # Ensure labels are horizontal
ax.legend(title='Churn', loc='upper right')
mp.show()

# %% [markdown]
# # comparitively more senior citizens have churned out

# %%
mp.figure(figsize=(9,5))
sns.histplot(x="tenure" , data=df , hue ="Churn" , bins=72)
mp.title("Timeline of people Churning")
mp.show()

# %% [markdown]
# # This histogram shows more people churned out in the initial month and the longest time people stayed were for 72 months.

# %%
mp.figure(figsize=(4,5))
ax=sns.countplot(x="Contract", data= df , hue="Churn" )
ax.bar_label(ax.containers[0])
mp.title("Count of Contract by Churn")
mp.show()

# %% [markdown]
# # People with month to month plan are more likely to churn then ones with yearly or longer plans.

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
# Define the columns for which we want to create count plots
columns = ['PhoneService', 'MultipleLines', 'InternetService',
           'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
           'TechSupport', 'StreamingTV', 'StreamingMovies']

# Determine the layout of the subplots
n_cols = 3  # Number of plots per row
n_rows = -(-len(columns) // n_cols)  # Calculate rows required (ceiling division)

# Create the figure and axes
fig, axes = mp.subplots(n_rows, n_cols, figsize=(15, 5 * n_rows))
axes = axes.flatten()  # Flatten to easily iterate over axes

# Plot each column
for idx, col in enumerate(columns):
    sns.countplot(data=df, x=col, ax=axes[idx], palette='viridis' , hue=df["Churn"])   # Explicitly set hue=None
    axes[idx].set_title(f'Count Plot for {col}')
    axes[idx].set_xlabel(col)
    axes[idx].set_ylabel('Count')

# Remove any unused subplots
for idx in range(len(columns), len(axes)):
    fig.delaxes(axes[idx])  # Remove unused axes

# Adjust layout to avoid overlap
mp.tight_layout()
mp.show()

# %% [markdown]
# # Key observations show higher churn rates for customers using Fiber optic InternetService and those lacking value-added services like OnlineSecurity, DeviceProtection, and TechSupport. The KPIs include churn rate by service type and service adoption levels, highlighting retention gaps in premium services.

# %%
mp.figure(figsize=(6,5))
ax=sns.countplot(x="PaymentMethod", data= df , hue="Churn" )
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
mp.title("Count of PaymentMethod by Churn")
mp.xticks( rotation=45)
mp.show()

# %% [markdown]
# # Customers are likely to churn when using electronic check as payment method
